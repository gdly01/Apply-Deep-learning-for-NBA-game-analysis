# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", None)
df = pd.read_csv('./data/NBA-BoxScores-2023-2024.csv')

# %%
# 檢視前五筆的資料
df.head()
# Out:
#    Unnamed: 0   GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0           0  22300061  1610612747               LAL  Los Angeles    1627752
# 1           1  22300061  1610612747               LAL  Los Angeles       2544
# 2           2  22300061  1610612747               LAL  Los Angeles     203076
# 3           3  22300061  1610612747               LAL  Los Angeles    1630559
# 4           4  22300061  1610612747               LAL  Los Angeles    1626156
#
#         PLAYER_NAME  NICKNAME START_POSITION COMMENT           MIN   FGM  \
# 0    Taurean Prince   Taurean              F     NaN  29.000000:53   6.0
# 1      LeBron James    LeBron              F     NaN  29.000000:01  10.0
# 2     Anthony Davis   Anthony              C     NaN  34.000000:09   6.0
# 3     Austin Reaves    Austin              G     NaN  31.000000:20   4.0
# 4  D'Angelo Russell  D'Angelo              G     NaN  36.000000:11   4.0
#
# ...

# %%
# 檢視最後五筆的資料
df.tail()
# Out:
#        Unnamed: 0   GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  \
# 23381          20  22300852  1610612752               NYK  New York
# 23382          21  22300852  1610612752               NYK  New York
# 23383          22  22300852  1610612752               NYK  New York
# 23384          23  22300852  1610612752               NYK  New York
# 23385          24  22300852  1610612752               NYK  New York
#
#        PLAYER_ID        PLAYER_NAME NICKNAME START_POSITION  \
# 23381     202692         Alec Burks     Alec            NaN
# 23382    1630540      Miles McBride    Miles            NaN
# 23383    1629718  Charlie Brown Jr.  Charlie            NaN
# 23384    1629610    DaQuan Jeffries   DaQuan            NaN
# 23385    1631210       Jacob Toppin    Jacob            NaN
#
#                       COMMENT           MIN  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 23381                     NaN  11.000000:13  2.0  6.0   0.333   1.0   3.0
# ...

# %%
# 檢視數據的欄位名稱
df.columns
# Out:
# Index(['Unnamed: 0', 'GAME_ID', 'TEAM_ID', 'TEAM_ABBREVIATION', 'TEAM_CITY',
#        'PLAYER_ID', 'PLAYER_NAME', 'NICKNAME', 'START_POSITION', 'COMMENT',
#        'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA',
#        'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TO', 'PF', 'PTS',
#        'PLUS_MINUS'],
#       dtype='object')

# %%
# 檢視數據欄、列的數量
df.shape
# Out:
# (23386, 30)

# %%
# 檢視各個欄位的資料型態與該欄位的資料數量
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23386 entries, 0 to 23385
# Data columns (total 30 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Unnamed: 0         23386 non-null  int64
#  1   GAME_ID            23386 non-null  int64
#  2   TEAM_ID            23386 non-null  int64
#  3   TEAM_ABBREVIATION  23386 non-null  object
#  4   TEAM_CITY          23386 non-null  object
#  5   PLAYER_ID          23386 non-null  int64
#  6   PLAYER_NAME        23386 non-null  object
#  7   NICKNAME           23386 non-null  object
#  8   START_POSITION     8850 non-null   object
#  9   COMMENT            4346 non-null   object
#  10  MIN                19040 non-null  object
#  11  FGM                19040 non-null  float64
#  12  FGA                19040 non-null  float64
#  13  FG_PCT             19040 non-null  float64
#  14  FG3M               19040 non-null  float64
#  15  FG3A               19040 non-null  float64
# ...

# %%
# 檢視整體資料的標準差、平均值等基本統計資料
df.describe()
# Out:
#          Unnamed: 0       GAME_ID       TEAM_ID     PLAYER_ID           FGM  \
# count  23386.000000  2.338600e+04  2.338600e+04  2.338600e+04  19040.000000
# mean      12.759771  2.230045e+07  1.610613e+09  1.334540e+06      3.941544
# std        7.704724  2.820759e+02  8.611397e+00  5.799039e+05      3.350429
# min        0.000000  2.230000e+07  1.610613e+09  2.544000e+03      0.000000
# 25%        6.000000  2.230022e+07  1.610613e+09  1.626224e+06      1.000000
# 50%       13.000000  2.230044e+07  1.610613e+09  1.629628e+06      3.000000
# 75%       19.000000  2.230066e+07  1.610613e+09  1.630577e+06      6.000000
# max       29.000000  2.230123e+07  1.610613e+09  1.641998e+06     25.000000
#
#                 FGA        FG_PCT         FG3M          FG3A       FG3_PCT  \
# count  19040.000000  19040.000000  19040.00000  19040.000000  19040.000000
# mean       8.293330      0.437226      1.19375      3.252784      0.267208
# ...

# %%
indexDNP = df[ (df['COMMENT'] == 'DNP - Coach\'s Decision') ] .index
df.drop(indexDNP , inplace=True)

# %%
columns = ['Unnamed: 0', 'TEAM_CITY', 'NICKNAME', 'START_POSITION', 'COMMENT', 'MIN']
df_clean = df.drop(columns, axis=1)

# %%
df_clean.dropna(inplace=True)

# %%
df_clean.isnull().sum().sum()
# Out:
# 0

# %%
df_clean.head()
# Out:
#     GAME_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_ID       PLAYER_NAME   FGM  \
# 0  22300061  1610612747               LAL    1627752    Taurean Prince   6.0
# 1  22300061  1610612747               LAL       2544      LeBron James  10.0
# 2  22300061  1610612747               LAL     203076     Anthony Davis   6.0
# 3  22300061  1610612747               LAL    1630559     Austin Reaves   4.0
# 4  22300061  1610612747               LAL    1626156  D'Angelo Russell   4.0
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# 0   8.0   0.750   4.0   6.0    0.667  2.0  2.0   1.000   1.0   2.0  3.0  1.0
# 1  16.0   0.625   1.0   4.0    0.250  0.0  1.0   0.000   1.0   7.0  8.0  5.0
# 2  17.0   0.353   1.0   2.0    0.500  4.0  4.0   1.000   1.0   7.0  8.0  4.0
# 3  11.0   0.364   1.0   2.0    0.500  5.0  7.0   0.714   4.0   4.0  8.0  4.0
# 4  12.0   0.333   2.0   5.0    0.400  1.0  2.0   0.500   0.0   4.0  4.0  7.0
#
#    STL  BLK   TO   PF   PTS  PLUS_MINUS
# ...
